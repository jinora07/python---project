# %%
import numpy as np
import pandas as pd
# !pip install datetime
import datetime

# %%
# prompt: warnings.filterwarnings('ignore')

import warnings
warnings.filterwarnings('ignore')

# %%
# prompt: import file from google drive

import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd '/content/drive/My Drive/'
# Out:
# /content/drive/My Drive

# %%
data = pd.read_excel("BangTheoDoiCN.xlsx","Sheet3")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 373 entries, 0 to 372
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CTY           276 non-null    object
#  1   MaHopDong     373 non-null    object
#  2   TenKhachHang  282 non-null    object
#  3   MaCongTrinh   286 non-null    object
#  4   TeamDA        260 non-null    object
#  5   CBCN          148 non-null    object
#  6   TenCongTrinh  289 non-null    object
#  7   Thang         373 non-null    object
#  8   Value         373 non-null    float64
# dtypes: float64(1), object(8)
# memory usage: 26.4+ KB

# %%
data.columns
# Out:
# Index(['CTY', 'MaHopDong', 'TenKhachHang', 'MaCongTrinh', 'TeamDA', 'CBCN',
#        'TenCongTrinh', 'Thang', 'Value'],
#       dtype='object')

# %%
data['Value'] = data['Value'].astype(int)

# %%
data.groupby('Thang')['Value'].sum()
# Out:
# Thang
# 1/1/2024     772232366824
# 10/1/2023    966676254155
# 11/1/2023    904307782238
# 12/1/2023    867082907318
# 2/1/2024     701162818469
# 3/1/2024     396472285108
# 4/1/2024     682028439542
# Name: Value, dtype: int64

# %%
data_nonNA = data[(data.Value.notnull() |data.Value.notna()) & (data.TenCongTrinh.notnull() |data.TenCongTrinh.notna())]
data_nonNA.head()
# Out:
#     CTY            MaHopDong                      TenKhachHang  \
# 0    D3  02-24/HĐTC -DDC III         CÔNG TY TNHH SỮA NUTRIBIZ
# 1    D3  02-24/HĐTC -DDC III         CÔNG TY TNHH SỮA NUTRIBIZ
# 2    D2   10-23/HĐTC -DDC II  CÔNG TY CỔ PHẦN XÂY DỰNG CENTRAL
# 3    D2   10-23/HĐTC -DDC II  CÔNG TY CỔ PHẦN XÂY DỰNG CENTRAL
# 4  DCAM     02-23/HĐXK-DDCAM      PH ECO CONSTRUCTION CO., LTD
#
#       MaCongTrinh          TeamDA CBCN  \
# 0  TCTN.D3.24.005  Trương Xuân Cơ  NaN
# 1  TCTN.D3.24.005  Trương Xuân Cơ  NaN
# 2  TCTN.D2.23.012  Trương Xuân Cơ  NaN
# 3  TCTN.D2.23.012  Trương Xuân Cơ  NaN
# 4  DCAM.23.002_D2  Trương Xuân Cơ  NaN
#
#                                         TenCongTrinh      Thang       Value
# 0                  NHÀ MÁY SỮA NUTRIBIZ GIAI ĐOẠN 2    1/1/2024  6694454000
# 1                  NHÀ MÁY SỮA NUTRIBIZ GIAI ĐOẠN 2    4/1/2024  2600297201
# 2  KHU PHỨC HỢP THƯƠNG MẠI VÀ CĂN HỘ CAO CẤP VẠN ...   1/1/2024  2695963657
# ...

# %%
#data_nonNA['Thang'] = data_nonNA.apply(lambda x: x['Thang'] if pd.notna(x['Thang']) else datetime.datetime(2023, 11, 1), axis = 1)
#data_nonNA

# %%
data_nonNA = data_nonNA.drop('CTY',axis=1)
data_nonNA
# Out:
#                MaHopDong                               TenKhachHang  \
# 0    02-24/HĐTC -DDC III                  CÔNG TY TNHH SỮA NUTRIBIZ
# 1    02-24/HĐTC -DDC III                  CÔNG TY TNHH SỮA NUTRIBIZ
# 2     10-23/HĐTC -DDC II           CÔNG TY CỔ PHẦN XÂY DỰNG CENTRAL
# 3     10-23/HĐTC -DDC II           CÔNG TY CỔ PHẦN XÂY DỰNG CENTRAL
# 4       02-23/HĐXK-DDCAM               PH ECO CONSTRUCTION CO., LTD
# ..                   ...                                        ...
# 368      35-21/HĐGC -DDC              CTY CP ĐT XD XUÂN MAI SÀI GÒN
# 369      35-21/HĐGC -DDC              CTY CP ĐT XD XUÂN MAI SÀI GÒN
# 370      35-21/HĐGC -DDC              CTY CP ĐT XD XUÂN MAI SÀI GÒN
# 371     32-21/HĐTC - DDC                      CÔNG TY TNHH RI TA VÕ
# 372    23-18/HĐTC-DDC II  CÔNG TY TNHH CƠ NHIỆT ĐIỆN LẠNH BÁCH KHOA
#
#         MaCongTrinh          TeamDA  CBCN  \
# 0    TCTN.D3.24.005  Trương Xuân Cơ   NaN
# 1    TCTN.D3.24.005  Trương Xuân Cơ   NaN
# ...

# %%
# prompt: group value by thang with dtype as interger

data_nonNA.groupby('Thang')['Value'].sum()
# Out:
# Thang
# 1/1/2024     386116183412
# 10/1/2023    490044445627
# 11/1/2023    452253891118
# 12/1/2023    433541453658
# 2/1/2024     350731409234
# 3/1/2024     201869359746
# 4/1/2024     343627924199
# Name: Value, dtype: int64

# %%
time = datetime.date.today().strftime('%Y_%m_%d')
time
# Out:
# '2024_05_15'

# %%
data_nonNA.to_excel('data_nonNA_' + time + '.xlsx',inf_rep=True,sheet_name="DataCN",index=False)

# %%
# prompt: export file to google drive replace if file exist sheet exist

# data_nonNA.to_excel(r'/content/drive/My Drive/data_nonNA.xlsx',index=False,if_sheet_exists='replace')
